# %%
import pandas as pd
import oracledb

# %%
connection = oracledb.connect(
    user='lipinskik',
    password='kamilhaslo123',
    dsn='213.184.8.44:1521/orcl')

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_monthly_info_country", oracledb.CURSOR, ['Polska', '2023']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#    COUNTRY    MONTH  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  AVG_FEELSLIKEMAX  \
# 0   Polska  2023-01          4.8          0.9       2.9               2.9
# 1   Polska  2023-02          4.3         -1.6       1.5               1.6
# 2   Polska  2023-03          8.6          0.5       4.6               7.2
# 3   Polska  2023-04         12.0          3.5       7.8              11.2
# 4   Polska  2023-05         17.9          6.8      12.9              17.8
# 5   Polska  2023-06         23.1         11.8      17.8              23.0
# 6   Polska  2023-07         25.1         13.7      19.6              24.9
# 7   Polska  2023-08         24.7         15.1      19.7              24.9
# 8   Polska  2023-09         23.7         11.9      17.6              23.6
# 9   Polska  2023-10         14.9          7.1      10.9              14.7
# 10  Polska  2023-11          6.7          1.3       4.1               5.2
# 11  Polska  2023-12          4.6          0.5       2.6               1.9
#
#     AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  AVG_PRECIP  \
# 0               -2.5            0.1      0.9          87.2         2.9
# 1               -5.1           -1.7     -1.6          81.0         2.9
# 2               -2.5            2.2      0.1          75.3         1.5
# 3                1.3            6.3      2.8          73.6         1.4
# 4                5.8           12.4      5.3          64.1         1.2
# 5               11.6           17.8     10.7          66.9         1.4
# 6               13.7           19.5     12.4          67.0         1.8
# 7               15.0           19.8     14.8          75.7         2.9
# 8               11.8           17.6     12.8          75.9         0.8
# 9                5.8           10.3      7.9          83.2         2.0
# 10              -1.7            1.8      1.8          85.5         2.2
# 11              -3.5           -0.9      0.5          86.6         2.0
#
#     AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  AVG_WINDSPEED  \
# 0               9.7       0.4            1.3          37.4           19.6
# 1               9.6       0.3            1.9          41.4           22.3
# 2               9.9       0.2            0.8          43.0           22.3
# 3               8.9       0.1            0.3          35.0           18.9
# 4               3.6       0.0            0.0          36.4           18.9
# 5               5.8       0.0            0.0          33.6           17.6
# 6               7.2       0.0            0.0          39.2           18.6
# 7               9.8       0.0            0.0          34.6           17.1
# 8               3.6       0.0            0.0          29.0           15.6
# 9              10.1       0.0            0.0          39.5           20.1
# 10             14.4       0.3            0.9          38.7           20.3
# 11             13.3       0.4            3.4          44.8           24.0
#
#     AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  AVG_VISIBILITY
# 0         185.3                1015.8            87.2            15.3
# 1         235.8                1022.7            77.2            17.1
# 2         226.1                1009.9            75.3            19.3
# 3         175.4                1016.3            69.8            20.4
# 4         146.7                1021.3            54.8            24.7
# 5         171.5                1016.8            55.4            24.6
# 6         240.7                1012.5            59.6            26.2
# 7         207.4                1013.4            63.7            23.5
# 8         183.1                1019.4            45.3            21.9
# 9         206.4                1011.5            76.7            19.0
# 10        204.1                1006.2            80.3            18.1
# 11        214.0                1010.3            85.2            16.1

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_monthly_info_region", oracledb.CURSOR, ['Woj. Pomorskie', '2023']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#             REGION    MONTH  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  \
# 0   Woj. Pomorskie  2023-01          4.5          1.6       3.1
# 1   Woj. Pomorskie  2023-02          4.0         -0.2       2.0
# 2   Woj. Pomorskie  2023-03          6.9          0.4       3.7
# 3   Woj. Pomorskie  2023-04          9.9          4.1       6.9
# 4   Woj. Pomorskie  2023-05         16.2          7.0      12.1
# 5   Woj. Pomorskie  2023-06         21.1         12.7      17.1
# 6   Woj. Pomorskie  2023-07         21.8         13.6      17.8
# 7   Woj. Pomorskie  2023-08         22.3         15.5      18.7
# 8   Woj. Pomorskie  2023-09         22.3         13.3      17.7
# 9   Woj. Pomorskie  2023-10         13.3          7.4      10.3
# 10  Woj. Pomorskie  2023-11          6.0          2.0       4.1
# 11  Woj. Pomorskie  2023-12          5.3          1.8       3.5
#
#     AVG_FEELSLIKEMAX  AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  \
# 0                1.7              -2.4           -0.4      0.9          86.1
# 1                0.5              -4.6           -2.0     -0.9          81.5
# 2                4.5              -3.3            0.4     -0.1          77.7
# 3                8.4               1.1            4.6      2.9          76.8
# 4               16.0               5.5           11.4      5.4          66.0
# 5               21.1              12.5           17.1     11.4          71.0
# 6               21.9              13.6           17.8     12.9          74.7
# 7               22.4              15.5           18.7     15.0          80.3
# 8               22.3              13.2           17.7     13.7          78.6
# 9               12.9               5.0            9.0      7.2          82.2
# 10               3.6              -1.7            0.9      1.9          85.9
# 11               1.7              -2.9           -0.8      1.5          87.2
#
#     AVG_PRECIP  AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  \
# 0          0.9              8.2       0.3            0.3          38.3
# 1          0.9              7.9       0.3            1.5          45.1
# 2          1.1              8.3       0.3            0.7          42.2
# 3          0.8              6.4       0.0            0.0          32.2
# 4          0.5              1.9       0.0            0.0          32.5
# 5          1.2              4.0       0.0            0.0          28.4
# 6          2.5              8.7       0.0            0.0          34.3
# 7          2.3              8.1       0.0            0.2          32.3
# 8          0.5              4.2       0.0            0.0          26.3
# 9          2.2              8.9       0.0            0.0          41.9
# 10         2.8              9.6       0.2            1.3          35.6
# 11         2.1              9.8       0.1            1.4          52.2
#
#     AVG_WINDSPEED  AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  \
# 0            23.7        196.0                1013.5            87.3
# 1            26.5        230.3                1020.1            79.5
# 2            24.1        233.1                1007.4            72.0
# 3            21.3        141.0                1017.6            66.2
# 4            20.3        161.5                1022.5            45.1
# 5            18.9        144.6                1017.4            46.7
# 6            18.7        239.8                1011.3            62.4
# 7            18.7        187.9                1012.2            69.5
# 8            18.3        187.8                1018.5            48.8
# 9            24.4        196.7                1009.2            77.0
# 10           23.0        211.8                1003.9            80.7
# 11           30.5        236.4                1005.4            84.8
#
#     AVG_VISIBILITY
# 0             23.1
# 1             23.4
# 2             24.4
# 3             26.4
# 4             32.3
# 5             31.4
# 6             32.3
# 7             29.8
# 8             29.2
# 9             29.0
# 10            24.3
# 11            19.2

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_monthly_info_city", oracledb.CURSOR, ['Olsztyn', '2023']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#        CITY    MONTH  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  AVG_FEELSLIKEMAX  \
# 0   Olsztyn  2023-01          3.7          0.6       2.2               1.9
# 1   Olsztyn  2023-02          3.3         -1.3       1.0               0.6
# 2   Olsztyn  2023-03          6.7         -0.7       3.2               5.3
# 3   Olsztyn  2023-04         12.1          3.1       7.8              11.5
# 4   Olsztyn  2023-05         18.6          5.9      13.0              18.6
# 5   Olsztyn  2023-06         23.3         11.3      17.9              23.2
# 6   Olsztyn  2023-07         24.0         13.1      18.7              23.9
# 7   Olsztyn  2023-08         24.6         15.6      19.9              24.8
# 8   Olsztyn  2023-09         23.3         11.6      17.5              23.3
# 9   Olsztyn  2023-10         12.9          6.1       9.4              12.5
# 10  Olsztyn  2023-11          5.4          0.7       3.1               4.3
# 11  Olsztyn  2023-12          2.7         -0.4       1.2               0.3
#
#     AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  AVG_PRECIP  \
# 0               -3.0           -0.4      0.3          87.8        18.7
# 1               -4.4           -2.0     -2.1          80.7         3.8
# 2               -3.2            1.0     -0.9          76.0         7.3
# 3                1.3            6.5      2.4          72.0         1.3
# 4                5.2           12.8      3.1          54.9         0.3
# 5               11.2           17.8      9.4          62.0         1.3
# 6               13.1           18.7     11.7          67.2         0.9
# 7               15.6           19.9     14.3          72.9         3.6
# 8               11.6           17.5     12.5          74.8         0.5
# 9                4.6            8.5      6.6          84.1         1.4
# 10              -2.1            0.9      1.1          87.1         2.2
# 11              -4.1           -1.9     -0.2          90.9         1.6
#
#     AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  AVG_WINDSPEED  \
# 0               7.1       0.6            2.7          35.0           17.0
# 1               5.7       0.2            1.2          36.2           18.8
# 2               6.3       0.3            0.9          38.5           19.3
# 3               5.3       0.0            0.0          34.4           16.9
# 4               1.9       0.0            0.0          33.6           16.9
# 5               3.6       0.0            0.0          28.3           17.3
# 6               5.5       0.0            0.0          36.0           17.7
# 7               5.6       0.0            0.0          32.1           16.7
# 8               1.8       0.0            0.0          27.3           15.5
# 9               6.2       0.0            0.0          37.2           19.5
# 10              6.9       0.7            2.0          32.9           16.0
# 11              7.3       0.2            3.8          35.2           17.3
#
#     AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  AVG_VISIBILITY
# 0         189.8                1014.8            93.9            15.7
# 1         250.4                1020.5            79.5            21.4
# 2         223.5                1008.4            76.0            23.0
# 3         190.8                1017.1            66.6            29.1
# 4         157.2                1022.4            50.8            36.6
# 5         189.1                1017.0            54.2            34.4
# 6         255.5                1011.8            64.6            37.8
# 7         188.7                1012.7            69.0            33.6
# 8         187.5                1019.3            46.8            31.2
# 9         208.9                1010.2            80.8            24.0
# 10        193.1                1005.1            84.2            19.1
# 11        198.2                1009.3            92.0            13.4

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_quarterly_info_country", oracledb.CURSOR, ['Polska', '2023']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#   COUNTRY QUARTER  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  AVG_FEELSLIKEMAX  \
# 0  Polska  2023-1          6.0          0.0       3.0               4.0
# 1  Polska  2023-2         17.7          7.4      12.8              17.4
# 2  Polska  2023-3         24.5         13.6      19.0              24.5
# 3  Polska  2023-4          8.4          2.7       5.6               6.8
#
#    AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  AVG_PRECIP  \
# 0              -3.3            0.3     -0.1          81.2         2.4
# 1               6.2           12.2      6.3          68.2         1.3
# 2              13.5           19.0     13.3          72.8         1.9
# 3              -0.1            3.3      3.1          85.3         2.0
#
#    AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  AVG_WINDSPEED  \
# 0              9.8       0.3            1.3          40.6           21.4
# 1              6.1       0.0            0.1          35.0           18.5
# 2              6.9       0.0            0.0          34.3           17.1
# 3             12.6       0.2            1.6          41.4           21.7
#
#    AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  AVG_VISIBILITY
# 0        215.0                1015.9            80.0            17.3
# 1        164.4                1018.1            60.0            23.2
# 2        210.7                1015.0            56.3            23.9
# 3        208.7                1009.5            81.1            17.5

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_quarterly_info_region", oracledb.CURSOR, ['Woj. Pomorskie', '2023']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#            REGION QUARTER  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  \
# 0  Woj. Pomorskie  2023-1          5.2          0.6       3.0
# 1  Woj. Pomorskie  2023-2         15.7          7.9      12.0
# 2  Woj. Pomorskie  2023-3         22.2         14.2      18.1
# 3  Woj. Pomorskie  2023-4          7.2          3.1       5.1
#
#    AVG_FEELSLIKEMAX  AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  \
# 0               2.3              -3.4           -0.6      0.0          81.8
# 1              15.2               6.4           11.0      6.5          71.2
# 2              22.2              14.1           18.1     13.9          77.8
# 3               4.6              -0.9            1.7      2.8          85.8
#
#    AVG_PRECIP  AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  \
# 0         1.0              8.1       0.3            0.8          41.7
# 1         0.8              4.1       0.0            0.0          31.1
# 2         1.8              7.0       0.0            0.1          31.0
# 3         2.3              9.5       0.1            1.0          46.4
#
#    AVG_WINDSPEED  AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  \
# 0           24.8        219.5                1013.5            79.6
# 1           20.2        149.2                1019.2            52.6
# 2           18.6        205.3                1013.9            60.4
# 3           27.6        222.3                1005.9            82.2
#
#    AVG_VISIBILITY
# 0            23.6
# 1            30.1
# 2            30.5
# 3            22.5

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_quarterly_info_city", oracledb.CURSOR, ['Olsztyn', '2023']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#       CITY QUARTER  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  AVG_FEELSLIKEMAX  \
# 0  Olsztyn  2023-1          4.6         -0.4       2.2               2.7
# 1  Olsztyn  2023-2         18.0          6.8      12.9              17.7
# 2  Olsztyn  2023-3         24.0         13.5      18.7              24.0
# 3  Olsztyn  2023-4          7.0          2.1       4.6               5.7
#
#    AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  AVG_PRECIP  \
# 0              -3.5           -0.4     -0.9          81.5        10.1
# 1               5.9           12.4      4.9          62.9         1.0
# 2              13.4           18.7     12.8          71.6         1.6
# 3              -0.5            2.5      2.5          87.4         1.7
#
#    AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  AVG_WINDSPEED  \
# 0              6.4       0.4            1.6          36.6           18.3
# 1              3.6       0.0            0.0          32.1           17.0
# 2              4.3       0.0            0.0          31.9           16.6
# 3              6.8       0.3            2.0          35.1           17.6
#
#    AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  AVG_VISIBILITY
# 0        220.3                1014.4            83.3            20.0
# 1        178.8                1018.9            57.1            33.4
# 2        210.8                1014.5            60.2            34.3
# 3        200.1                1008.2            85.7            18.8

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_yearly_info_country", oracledb.CURSOR, ['Polska']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#   COUNTRY  YEAR  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  AVG_FEELSLIKEMAX  \
# 0  Polska  2023         14.0          5.9        10              13.0
# 1  Polska  2024          0.3         -4.7        -2              -2.9
#
#    AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  AVG_PRECIP  \
# 0               4.0            8.6      5.6          77.1         1.9
# 1              -9.7           -6.2     -4.2          85.2         1.5
#
#    AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  AVG_WINDSPEED  \
# 0              8.9       0.1            0.8          37.9           19.7
# 1             16.3       0.6            4.4          39.4           22.9
#
#    AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  AVG_VISIBILITY
# 0        199.9                1014.5            69.6            20.4
# 1        195.5                1012.4            79.1            14.2

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_yearly_info_region", oracledb.CURSOR, ['Woj. Pomorskie']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#            REGION  YEAR  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  AVG_FEELSLIKEMAX  \
# 0  Woj. Pomorskie  2023         12.0          6.1       9.1              10.3
# 1  Woj. Pomorskie  2024          0.1         -3.6      -1.6              -3.7
#
#    AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  AVG_PRECIP  \
# 0               3.5            6.9      5.5          79.9         1.6
# 1              -9.1           -6.5     -3.6          86.5         1.7
#
#    AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  AVG_WINDSPEED  \
# 0              7.5       0.1            0.6          38.6           23.3
# 1             19.6       0.5            2.8          38.0           25.3
#
#    AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  AVG_VISIBILITY
# 0        201.8                1012.3            70.2            26.2
# 1        187.4                1011.5            83.8            17.1

# %%
cursor = connection.cursor()

weather_info_cursor = cursor.callfunc("z_get_weather_avg_yearly_info_city", oracledb.CURSOR, ['Olsztyn']) 
                                                                                 

weather_info = weather_info_cursor.fetchall()
cursor.close()

columns = [desc[0] for desc in weather_info_cursor.description]
df = pd.DataFrame(weather_info, columns=columns)

df
# Out:
#       CITY  YEAR  AVG_TEMPMAX  AVG_TEMPMIN  AVG_TEMP  AVG_FEELSLIKEMAX  \
# 0  Olsztyn  2023         13.4          5.5       9.6              12.6
# 1  Olsztyn  2024         -1.6         -7.4      -4.0              -4.6
#
#    AVG_FEELSLIKEMIN  AVG_FEELSLIKE  AVG_DEW  AVG_HUMIDITY  AVG_PRECIP  \
# 0               3.9            8.3      4.9          75.8         3.6
# 1             -11.8           -7.9     -5.6          89.1         1.1
#
#    AVG_PRECIPCOVER  AVG_SNOW  AVG_SNOWDEPTH  AVG_WINDGUST  AVG_WINDSPEED  \
# 0              5.3       0.2            0.9          33.9           17.4
# 1             12.3       0.7            8.3          36.2           18.6
#
#    AVG_WINDDIR  AVG_SEALEVELPRESSURE  AVG_CLOUDCOVER  AVG_VISIBILITY
# 0        202.5                1014.0            71.6            26.6
# 1        181.5                1011.1            81.4            11.1
